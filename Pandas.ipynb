# %% [markdown]
# #text dictionary list excel cvs github html json

# %% [markdown]
# #pip instal pandas

# %%
import  pandas as pd

# %% [markdown]
# #read data

# %%
pd.read_csv("D:\index\python4-5pm\car_data1.csv")
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df = pd.read_csv(r"D:\index\python4-5pm\car_data1.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel("D:\index\python4-5pm\Titanic.xlsx")
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
pd.read_excel("D:\index\python4-5pm\Titanic.xlsx",sheet_name='abc')
# Out:
#      1                            Braund, Mr. Owen Harris
# 0    2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1    3                             Heikkinen, Miss. Laina
# 2    4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3    5                           Allen, Mr. William Henry
# 4    6                                   Moran, Mr. James
# 5    7                            McCarthy, Mr. Timothy J
# 6    8                     Palsson, Master. Gosta Leonard
# 7    9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8   10                Nasser, Mrs. Nicholas (Adele Achem)
# 9   11                    Sandstrom, Miss. Marguerite Rut
# 10  12                           Bonnell, Miss. Elizabeth

# %%
df = pd.read_excel("D:\index\python4-5pm\Titanic.xlsx",header=None,)

# %%
pd.read_excel("D:\index\python4-5pm\Titanic.xlsx",sheet_name='abc',header=None,names=['index','passenger'])
# Out:
#     index                                          passenger
# 0       1                            Braund, Mr. Owen Harris
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3                             Heikkinen, Miss. Laina
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5                           Allen, Mr. William Henry
# 5       6                                   Moran, Mr. James
# 6       7                            McCarthy, Mr. Timothy J
# 7       8                     Palsson, Master. Gosta Leonard
# 8       9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9      10                Nasser, Mrs. Nicholas (Adele Achem)
# 10     11                    Sandstrom, Miss. Marguerite Rut
# 11     12                           Bonnell, Miss. Elizabeth

# %%
pd.read_excel("D:\index\python4-5pm\Titanic.xlsx",sheet_name='Sheet1',header=None,names=['A', 'B', 'C'])
# Out:
#                                                                                                                            A  \
# PassengerId Name                                               Pclass Sex    Age SibSp Parch Ticket           Fare     Cabin
# 1           Braund, Mr. Owen Harris                            3      male   22  1     0     A/5 21171        7.25       NaN
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha... 1      female 38  1     0     PC 17599         71.2833    C85
# 3           Heikkinen, Miss. Laina                             3      female 26  0     0     STON/O2. 3101282 7.925      NaN
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)       1      female 35  1     0     113803           53.1      C123
# ...                                                                                                                      ...
# ...

# %%
df
# Out:
#               0                                                  1       2   \
# 0    PassengerId                                               Name  Pclass
# 1              1                            Braund, Mr. Owen Harris       3
# 2              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3              3                             Heikkinen, Miss. Laina       3
# 4              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# ..           ...                                                ...     ...
# 887          887                              Montvila, Rev. Juozas       2
# 888          888                       Graham, Miss. Margaret Edith       1
# 889          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 890          890                              Behr, Mr. Karl Howell       1
# 891          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.head()
# Out:
#             0                                                  1       2   \
# 0  PassengerId                                               Name  Pclass
# 1            1                            Braund, Mr. Owen Harris       3
# 2            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3            3                             Heikkinen, Miss. Laina       3
# 4            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
#
#        3    4      5      6                 7        8      9         10  \
# 0     Sex  Age  SibSp  Parch            Ticket     Fare  Cabin  Embarked
# 1    male   22      1      0         A/5 21171     7.25    NaN         S
# 2  female   38      1      0          PC 17599  71.2833    C85         C
# 3  female   26      0      0  STON/O2. 3101282    7.925    NaN         S
# 4  female   35      1      0            113803     53.1   C123         S
#
#          11
# 0  Survived
# 1         0
# 2         1
# 3         1
# 4         1

# %%
df.tail()
# Out:
#       0                                         1  2       3    4  5  6   \
# 887  887                     Montvila, Rev. Juozas  2    male   27  0  0
# 888  888              Graham, Miss. Margaret Edith  1  female   19  0  0
# 889  889  Johnston, Miss. Catherine Helen "Carrie"  3  female  NaN  1  2
# 890  890                     Behr, Mr. Karl Howell  1    male   26  0  0
# 891  891                       Dooley, Mr. Patrick  3    male   32  0  0
#
#              7      8     9  10 11
# 887      211536     13   NaN  S  0
# 888      112053     30   B42  S  1
# 889  W./C. 6607  23.45   NaN  S  0
# 890      111369     30  C148  C  1
# 891      370376   7.75   NaN  Q  0

# %%
df.head(10)
# Out:
#             0                                                  1       2   \
# 0  PassengerId                                               Name  Pclass
# 1            1                            Braund, Mr. Owen Harris       3
# 2            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3            3                             Heikkinen, Miss. Laina       3
# 4            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 5            5                           Allen, Mr. William Henry       3
# 6            6                                   Moran, Mr. James       3
# 7            7                            McCarthy, Mr. Timothy J       1
# 8            8                     Palsson, Master. Gosta Leonard       3
# 9            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
#
#        3    4      5      6                 7        8      9         10  \
# 0     Sex  Age  SibSp  Parch            Ticket     Fare  Cabin  Embarked
# ...

# %%
df.tail(10)
# Out:
#       0                                         1  2       3    4  5  6   \
# 882  882                        Markun, Mr. Johann  3    male   33  0  0
# 883  883              Dahlberg, Miss. Gerda Ulrika  3  female   22  0  0
# 884  884             Banfield, Mr. Frederick James  2    male   28  0  0
# 885  885                    Sutehall, Mr. Henry Jr  3    male   25  0  0
# 886  886      Rice, Mrs. William (Margaret Norton)  3  female   39  0  5
# 887  887                     Montvila, Rev. Juozas  2    male   27  0  0
# 888  888              Graham, Miss. Margaret Edith  1  female   19  0  0
# 889  889  Johnston, Miss. Catherine Helen "Carrie"  3  female  NaN  1  2
# 890  890                     Behr, Mr. Karl Howell  1    male   26  0  0
# 891  891                       Dooley, Mr. Patrick  3    male   32  0  0
#
#                    7        8     9  10 11
# 882            349257   7.8958   NaN  S  0
# 883              7552  10.5167   NaN  S  0
# ...

# %%
df.shape
# Out:
# (892, 12)

# %%
df.head()
# Out:
#             0                                                  1       2   \
# 0  PassengerId                                               Name  Pclass
# 1            1                            Braund, Mr. Owen Harris       3
# 2            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3            3                             Heikkinen, Miss. Laina       3
# 4            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
#
#        3    4      5      6                 7        8      9         10  \
# 0     Sex  Age  SibSp  Parch            Ticket     Fare  Cabin  Embarked
# 1    male   22      1      0         A/5 21171     7.25    NaN         S
# 2  female   38      1      0          PC 17599  71.2833    C85         C
# 3  female   26      0      0  STON/O2. 3101282    7.925    NaN         S
# 4  female   35      1      0            113803     53.1   C123         S
#
#          11
# 0  Survived
# 1         0
# 2         1
# 3         1
# 4         1

# %%
df.shape
# Out:
# (892, 12)

# %%
d = {"key":"value","age":21}

# %%
d['age']
# Out:
# 21

# %%
df.head()
# Out:
#             0                                                  1       2   \
# 0  PassengerId                                               Name  Pclass
# 1            1                            Braund, Mr. Owen Harris       3
# 2            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3            3                             Heikkinen, Miss. Laina       3
# 4            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
#
#        3    4      5      6                 7        8      9         10  \
# 0     Sex  Age  SibSp  Parch            Ticket     Fare  Cabin  Embarked
# 1    male   22      1      0         A/5 21171     7.25    NaN         S
# 2  female   38      1      0          PC 17599  71.2833    C85         C
# 3  female   26      0      0  STON/O2. 3101282    7.925    NaN         S
# 4  female   35      1      0            113803     53.1   C123         S
#
#          11
# 0  Survived
# 1         0
# 2         1
# 3         1
# 4         1

# %%
pd.read_excel("D:\index\python4-5pm\Titanic.xlsx")
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df = pd.read_excel("D:\index\python4-5pm\Titanic.xlsx")

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df['Name'].dtype
# Out:
# dtype('O')

# %%
df['Embarked'].dtype
# Out:
# dtype('O')

# %%
df[['Age','Name']]
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
type(df[['Age','Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
df[df.dtypes[df.dtypes == "float"].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df[df.dtypes[df.dtypes == "int"].index].describe()
# Out:
#        PassengerId      Pclass       SibSp       Parch    Survived
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642    0.523008    0.381594    0.383838
# std     257.353842    0.836071    1.102743    0.806057    0.486592
# min       1.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000    0.000000    0.000000    0.000000
# 50%     446.000000    3.000000    0.000000    0.000000    0.000000
# 75%     668.500000    3.000000    1.000000    0.000000    1.000000
# max     891.000000    3.000000    8.000000    6.000000    1.000000

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
df1=pd.read_csv("D:\index\python4-5pm\car_data1.csv")

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df1[1:5]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df1[1:7]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
#
#   Seller_Type Transmission  Owner
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0

# %%
df1[1:7:2]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner
# 1      Dealer       Manual      0
# 3      Dealer       Manual      0
# 5      Dealer       Manual      0

# %%
df1['Car_Name'][1:7]
# Out:
# 1              sx4
# 2             ciaz
# 3          wagon r
# 4            swift
# 5    vitara brezza
# 6             ciaz
# Name: Car_Name, dtype: object

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
d ={"key":"value"}

# %%
d ['age']= 21

# %%
d
# Out:
# {'key': 'value', 'age': 21}

# %%
df1=pd.read_csv("D:\index\python4-5pm\car_data1.csv")

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Differnce
# ...

# %%
df1["Current_Year"]= 2025

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year
# 0        Dealer       Manual      0          2025
# ...

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year
# 0      Dealer       Manual      0          2025
# 1      Dealer       Manual      0          2025
# 2      Dealer       Manual      0          2025
# 3      Dealer       Manual      0          2025
# 4      Dealer       Manual      0          2025

# %%
df1['Current_Year']-df1['Year']
# Out:
# 0      11
# 1      12
# 2       8
# 3      14
# 4      11
#        ..
# 296     9
# 297    10
# 298    16
# 299     8
# 300     9
# Length: 301, dtype: int64

# %%
df1['Differnce']=df1['Current_Year']-df1['Year']

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Differnce
# ...

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce
# 0      Dealer       Manual      0          2025         11
# 1      Dealer       Manual      0          2025         12
# 2      Dealer       Manual      0          2025          8
# 3      Dealer       Manual      0          2025         14
# 4      Dealer       Manual      0          2025         11

# %%
df1.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner  Current_Year  Differnce
# ...

# %%
df1.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Current_Year     0
# Differnce        0
# dtype: int64

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce
# 0      Dealer       Manual      0          2025         11
# 1      Dealer       Manual      0          2025         12
# 2      Dealer       Manual      0          2025          8
# 3      Dealer       Manual      0          2025         14
# 4      Dealer       Manual      0          2025         11

# %%
max(df1['Kms_Driven'])
# Out:
# 500000

# %%
df1['Kms_Driven']==max(df1['Kms_Driven'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Name: Kms_Driven, Length: 301, dtype: bool

# %%
df1[df1['Kms_Driven']==max(df1['Kms_Driven'])]
# Out:
#       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 196  Activa 3g  2008           0.17           0.52      500000    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Differnce
# 196  Individual    Automatic      0          2025         17

# %%
df1[df1['Kms_Driven']==max(df1['Kms_Driven'])]['Year']
# Out:
# 196    2008
# Name: Year, dtype: int64

# %%
df1[df1['Kms_Driven']==max(df1['Kms_Driven'])]['Car_Name']
# Out:
# 196    Activa 3g
# Name: Car_Name, dtype: object

# %%
df1[df1['Year']==2014]
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                    ritz  2014           3.35          5.590       27000
# 4                   swift  2014           4.60          6.870       42450
# 23               alto k10  2014           2.50          3.460       45280
# 32                  swift  2014           4.95          7.490       39000
# 33                 ertiga  2014           6.00          9.950       45000
# 34                  dzire  2014           5.50          8.060       45000
# 41               alto k10  2014           2.55          3.980       46706
# 43                  dzire  2014           5.50          8.060       45780
# 45                   ciaz  2014           7.50         12.040       15000
# 58                etios g  2014           4.10          6.800       39485
# 59               fortuner  2014          19.99         35.960       41000
# 62               fortuner  2014          18.75         35.960       78000
# ...

# %%
df1[df1['Year']==2014].shape
# Out:
# (38, 11)

# %%
len(df1[df1['Year']==2014])
# Out:
# 38

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce
# 0      Dealer       Manual      0          2025         11
# 1      Dealer       Manual      0          2025         12
# 2      Dealer       Manual      0          2025          8
# 3      Dealer       Manual      0          2025         14
# 4      Dealer       Manual      0          2025         11

# %%
(df1['Year']<2014) & (df1['Kms_Driven']<70000)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
df1[(df1['Year']<2014) & (df1['Kms_Driven']<7000)]
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 3                      wagon r  2011           2.85          4.150
# 119  Royal Enfield Thunder 500  2013           1.05          1.900
# 121  Royal Enfield Thunder 350  2011           1.05          1.500
# 150         TVS Apache RTR 180  2011           0.50          0.826
# 170               Yamaha FZ S   2012           0.40          0.830
# 185          Suzuki Access 125  2008           0.25          0.580
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Current_Year  \
# 3          5200    Petrol      Dealer       Manual      0          2025
# 119        5400    Petrol  Individual       Manual      0          2025
# 121        6900    Petrol  Individual       Manual      0          2025
# 150        6000    Petrol  Individual       Manual      0          2025
# 170        5500    Petrol  Individual       Manual      0          2025
# ...

# %%
df2 = pd.read_csv("D:\daily_total_births.csv")

# %%
df2
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
df2.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
df2.tail()
# Out:
#            Date  Births
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50

# %%
df2.shape
# Out:
# (365, 2)

# %%
df2.isnull().sum()
# Out:
# Date      0
# Births    0
# dtype: int64

# %%
df2.describe()
# Out:
#            Births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   Births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
date = pd.to_datetime(df2['Date'])

# %%
date
# Out:
# 0     1959-01-01
# 1     1959-01-02
# 2     1959-01-03
# 3     1959-01-04
# 4     1959-01-05
#          ...
# 360   1959-12-27
# 361   1959-12-28
# 362   1959-12-29
# 363   1959-12-30
# 364   1959-12-31
# Name: Date, Length: 365, dtype: datetime64[ns]

# %%
df2.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
df2['coverted_date'] = date = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#            Date  Births coverted_date
# 0    1959-01-01      35    1959-01-01
# 1    1959-01-02      32    1959-01-02
# 2    1959-01-03      30    1959-01-03
# 3    1959-01-04      31    1959-01-04
# 4    1959-01-05      44    1959-01-05
# ..          ...     ...           ...
# 360  1959-12-27      37    1959-12-27
# 361  1959-12-28      52    1959-12-28
# 362  1959-12-29      48    1959-12-29
# 363  1959-12-30      55    1959-12-30
# 364  1959-12-31      50    1959-12-31
#
# [365 rows x 3 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           365 non-null    object
#  1   Births         365 non-null    int64
#  2   coverted_date  365 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
df2.head()
# Out:
#          Date  Births coverted_date
# 0  1959-01-01      35    1959-01-01
# 1  1959-01-02      32    1959-01-02
# 2  1959-01-03      30    1959-01-03
# 3  1959-01-04      31    1959-01-04
# 4  1959-01-05      44    1959-01-05

# %%
df2['Year'] = df2['coverted_date'].dt.year

# %%
df2.head()
# Out:
#          Date  Births coverted_date  Year
# 0  1959-01-01      35    1959-01-01  1959
# 1  1959-01-02      32    1959-01-02  1959
# 2  1959-01-03      30    1959-01-03  1959
# 3  1959-01-04      31    1959-01-04  1959
# 4  1959-01-05      44    1959-01-05  1959

# %%
df2['Month'] = df2['coverted_date'].dt.month

# %%
df2
# Out:
#            Date  Births coverted_date  Year  Month
# 0    1959-01-01      35    1959-01-01  1959      1
# 1    1959-01-02      32    1959-01-02  1959      1
# 2    1959-01-03      30    1959-01-03  1959      1
# 3    1959-01-04      31    1959-01-04  1959      1
# 4    1959-01-05      44    1959-01-05  1959      1
# ..          ...     ...           ...   ...    ...
# 360  1959-12-27      37    1959-12-27  1959     12
# 361  1959-12-28      52    1959-12-28  1959     12
# 362  1959-12-29      48    1959-12-29  1959     12
# 363  1959-12-30      55    1959-12-30  1959     12
# 364  1959-12-31      50    1959-12-31  1959     12
#
# [365 rows x 5 columns]

# %%
df2['week'] = df2['coverted_date'].dt.isocalendar().week

# %%
df2
# Out:
#            Date  Births coverted_date  Year  Month  week
# 0    1959-01-01      35    1959-01-01  1959      1     1
# 1    1959-01-02      32    1959-01-02  1959      1     1
# 2    1959-01-03      30    1959-01-03  1959      1     1
# 3    1959-01-04      31    1959-01-04  1959      1     1
# 4    1959-01-05      44    1959-01-05  1959      1     2
# ..          ...     ...           ...   ...    ...   ...
# 360  1959-12-27      37    1959-12-27  1959     12    52
# 361  1959-12-28      52    1959-12-28  1959     12    53
# 362  1959-12-29      48    1959-12-29  1959     12    53
# 363  1959-12-30      55    1959-12-30  1959     12    53
# 364  1959-12-31      50    1959-12-31  1959     12    53
#
# [365 rows x 6 columns]

# %%
df2['Month'].value_counts()
# Out:
# Month
# 1     31
# 3     31
# 7     31
# 5     31
# 12    31
# 10    31
# 8     31
# 4     30
# 9     30
# 6     30
# 11    30
# 2     28
# Name: count, dtype: int64

# %%
df2.head()
# Out:
#          Date  Births coverted_date  Year  Month  week
# 0  1959-01-01      35    1959-01-01  1959      1     1
# 1  1959-01-02      32    1959-01-02  1959      1     1
# 2  1959-01-03      30    1959-01-03  1959      1     1
# 3  1959-01-04      31    1959-01-04  1959      1     1
# 4  1959-01-05      44    1959-01-05  1959      1     2

# %%
df2 = df2.drop('week',axis=1)

# %%
df2
# Out:
#            Date  Births coverted_date  Year  Month
# 0    1959-01-01      35    1959-01-01  1959      1
# 1    1959-01-02      32    1959-01-02  1959      1
# 2    1959-01-03      30    1959-01-03  1959      1
# 3    1959-01-04      31    1959-01-04  1959      1
# 4    1959-01-05      44    1959-01-05  1959      1
# ..          ...     ...           ...   ...    ...
# 360  1959-12-27      37    1959-12-27  1959     12
# 361  1959-12-28      52    1959-12-28  1959     12
# 362  1959-12-29      48    1959-12-29  1959     12
# 363  1959-12-30      55    1959-12-30  1959     12
# 364  1959-12-31      50    1959-12-31  1959     12
#
# [365 rows x 5 columns]

# %%
df2 = df2.drop(1)

# %%
df2
# Out:
#            Date  Births coverted_date  Year  Month
# 0    1959-01-01      35    1959-01-01  1959      1
# 2    1959-01-03      30    1959-01-03  1959      1
# 3    1959-01-04      31    1959-01-04  1959      1
# 4    1959-01-05      44    1959-01-05  1959      1
# 5    1959-01-06      29    1959-01-06  1959      1
# ..          ...     ...           ...   ...    ...
# 360  1959-12-27      37    1959-12-27  1959     12
# 361  1959-12-28      52    1959-12-28  1959     12
# 362  1959-12-29      48    1959-12-29  1959     12
# 363  1959-12-30      55    1959-12-30  1959     12
# 364  1959-12-31      50    1959-12-31  1959     12
#
# [364 rows x 5 columns]

# %%
df2.head()
# Out:
#          Date  Births coverted_date  Year  Month
# 0  1959-01-01      35    1959-01-01  1959      1
# 2  1959-01-03      30    1959-01-03  1959      1
# 3  1959-01-04      31    1959-01-04  1959      1
# 4  1959-01-05      44    1959-01-05  1959      1
# 5  1959-01-06      29    1959-01-06  1959      1

# %%
df2.loc[2]
# Out:
# Date                      1959-01-03
# Births                            30
# coverted_date    1959-01-03 00:00:00
# Year                            1959
# Month                              1
# Name: 2, dtype: object

# %%
df2.loc[[2,3]]
# Out:
#          Date  Births coverted_date  Year  Month
# 2  1959-01-03      30    1959-01-03  1959      1
# 3  1959-01-04      31    1959-01-04  1959      1

# %%
df2.loc[[50,23]]
# Out:
#           Date  Births coverted_date  Year  Month
# 50  1959-02-20      48    1959-02-20  1959      2
# 23  1959-01-24      32    1959-01-24  1959      1

# %%
df2.loc[2:7]
# Out:
#          Date  Births coverted_date  Year  Month
# 2  1959-01-03      30    1959-01-03  1959      1
# 3  1959-01-04      31    1959-01-04  1959      1
# 4  1959-01-05      44    1959-01-05  1959      1
# 5  1959-01-06      29    1959-01-06  1959      1
# 6  1959-01-07      45    1959-01-07  1959      1
# 7  1959-01-08      43    1959-01-08  1959      1

# %%
df2.loc[2:7:2]
# Out:
#          Date  Births coverted_date  Year  Month
# 2  1959-01-03      30    1959-01-03  1959      1
# 4  1959-01-05      44    1959-01-05  1959      1
# 6  1959-01-07      45    1959-01-07  1959      1

# %%
df2.loc[2:7,['Date','Births','coverted_date']]
# Out:
#          Date  Births coverted_date
# 2  1959-01-03      30    1959-01-03
# 3  1959-01-04      31    1959-01-04
# 4  1959-01-05      44    1959-01-05
# 5  1959-01-06      29    1959-01-06
# 6  1959-01-07      45    1959-01-07
# 7  1959-01-08      43    1959-01-08

# %%
df2.iloc[2:7,0:3]
# Out:
#          Date  Births coverted_date
# 3  1959-01-04      31    1959-01-04
# 4  1959-01-05      44    1959-01-05
# 5  1959-01-06      29    1959-01-06
# 6  1959-01-07      45    1959-01-07
# 7  1959-01-08      43    1959-01-08

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %% [markdown]
# #mean mode medain zero fill drop exact value

# %%
df.dropna()
# Out:
#      PassengerId                                               Name  Pclass  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 6              7                            McCarthy, Mr. Timothy J       1
# 10            11                    Sandstrom, Miss. Marguerite Rut       3
# 11            12                           Bonnell, Miss. Elizabeth       1
# ..           ...                                                ...     ...
# 871          872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1
# 872          873                           Carlsson, Mr. Frans Olof       1
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1
# 887          888                       Graham, Miss. Margaret Edith       1
# 889          890                              Behr, Mr. Karl Howell       1
#
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.dropna(thresh=3)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.dropna(thresh=1)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.fillna(4)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
data = {
    'name':['abc','def','ghi','hij'],
    'salary':[100,200,300,400],
    'mail_id':['abc@gmail.com','def@gmail.com','kgf@gmail.com','mno@gmail.com'],
    'addr':['mum','pune','mum','delhi']
}

# %%
df3 = pd.DataFrame(data,index=[4,5,6,7])

# %%
df3
# Out:
#   name  salary        mail_id   addr
# 4  abc     100  abc@gmail.com    mum
# 5  def     200  def@gmail.com   pune
# 6  ghi     300  kgf@gmail.com    mum
# 7  hij     400  mno@gmail.com  delhi

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df3 = pd.DataFrame(data)

# %%
df3
# Out:
#   name  salary        mail_id   addr
# 0  abc     100  abc@gmail.com    mum
# 1  def     200  def@gmail.com   pune
# 2  ghi     300  kgf@gmail.com    mum
# 3  hij     400  mno@gmail.com  delhi

# %%
data1 = {
    'pf_num':[234,456,234,566],
    'income_tax':[2334,5356,7478,3887],
    'mobile_num':[2334,5567,7765,5554],
    'course':['DS','DA','PFS','FS']
}

# %%
df4 = pd.DataFrame(data1)

# %%
df4
# Out:
#    pf_num  income_tax  mobile_num course
# 0     234        2334        2334     DS
# 1     456        5356        5567     DA
# 2     234        7478        7765    PFS
# 3     566        3887        5554     FS

# %%
df3
# Out:
#   name  salary        mail_id   addr
# 0  abc     100  abc@gmail.com    mum
# 1  def     200  def@gmail.com   pune
# 2  ghi     300  kgf@gmail.com    mum
# 3  hij     400  mno@gmail.com  delhi

# %%
df4
# Out:
#    pf_num  income_tax  mobile_num course
# 0     234        2334        2334     DS
# 1     456        5356        5567     DA
# 2     234        7478        7765    PFS
# 3     566        3887        5554     FS

# %%
df3+df4
# Out:
#   addr course  income_tax mail_id  mobile_num name  pf_num  salary
# 0  NaN    NaN         NaN     NaN         NaN  NaN     NaN     NaN
# 1  NaN    NaN         NaN     NaN         NaN  NaN     NaN     NaN
# 2  NaN    NaN         NaN     NaN         NaN  NaN     NaN     NaN
# 3  NaN    NaN         NaN     NaN         NaN  NaN     NaN     NaN

# %%
pd.concat([df3,df4])
# Out:
#   name  salary        mail_id   addr  pf_num  income_tax  mobile_num course
# 0  abc   100.0  abc@gmail.com    mum     NaN         NaN         NaN    NaN
# 1  def   200.0  def@gmail.com   pune     NaN         NaN         NaN    NaN
# 2  ghi   300.0  kgf@gmail.com    mum     NaN         NaN         NaN    NaN
# 3  hij   400.0  mno@gmail.com  delhi     NaN         NaN         NaN    NaN
# 0  NaN     NaN            NaN    NaN   234.0      2334.0      2334.0     DS
# 1  NaN     NaN            NaN    NaN   456.0      5356.0      5567.0     DA
# 2  NaN     NaN            NaN    NaN   234.0      7478.0      7765.0    PFS
# 3  NaN     NaN            NaN    NaN   566.0      3887.0      5554.0     FS

# %%
pd.concat([df3,df4])
# Out:
#   name  salary        mail_id   addr  pf_num  income_tax  mobile_num course
# 0  abc   100.0  abc@gmail.com    mum     NaN         NaN         NaN    NaN
# 1  def   200.0  def@gmail.com   pune     NaN         NaN         NaN    NaN
# 2  ghi   300.0  kgf@gmail.com    mum     NaN         NaN         NaN    NaN
# 3  hij   400.0  mno@gmail.com  delhi     NaN         NaN         NaN    NaN
# 0  NaN     NaN            NaN    NaN   234.0      2334.0      2334.0     DS
# 1  NaN     NaN            NaN    NaN   456.0      5356.0      5567.0     DA
# 2  NaN     NaN            NaN    NaN   234.0      7478.0      7765.0    PFS
# 3  NaN     NaN            NaN    NaN   566.0      3887.0      5554.0     FS

# %%
pd.concat([df3,df4],axis=1)
# Out:
#   name  salary        mail_id   addr  pf_num  income_tax  mobile_num course
# 0  abc     100  abc@gmail.com    mum     234        2334        2334     DS
# 1  def     200  def@gmail.com   pune     456        5356        5567     DA
# 2  ghi     300  kgf@gmail.com    mum     234        7478        7765    PFS
# 3  hij     400  mno@gmail.com  delhi     566        3887        5554     FS

# %%
data2 = {'0': ['abc', 'bcd', 'efg', 'hij'],
'1'  :[100, 200, 300, 400],
'2' :['abc@gmail.com','def@gmail.com','kgf@gmail.com','mno@gmail.com'],
'3' :['mum','pune','mum','delhi']
}           

data3 = {'0':[234,456,234,566],
'1' :[2334,5356,7478,3887],
'2' :[2334,5567,7765,5554],
'3' :['ds','bigdata','python','web']
}

# %%
df5 = pd.DataFrame(data2)
df6 = pd.DataFrame(data3,index=[4,5,6,7])

# %%
df5
# Out:
#      0    1              2      3
# 0  abc  100  abc@gmail.com    mum
# 1  bcd  200  def@gmail.com   pune
# 2  efg  300  kgf@gmail.com    mum
# 3  hij  400  mno@gmail.com  delhi

# %%
df6
# Out:
#      0     1     2        3
# 4  234  2334  2334       ds
# 5  456  5356  5567  bigdata
# 6  234  7478  7765   python
# 7  566  3887  5554      web

# %%
pd.concat([df5,df6])
# Out:
#      0     1              2        3
# 0  abc   100  abc@gmail.com      mum
# 1  bcd   200  def@gmail.com     pune
# 2  efg   300  kgf@gmail.com      mum
# 3  hij   400  mno@gmail.com    delhi
# 4  234  2334           2334       ds
# 5  456  5356           5567  bigdata
# 6  234  7478           7765   python
# 7  566  3887           5554      web

# %%
pd.concat([df5,df6],axis=1)
# Out:
#      0      1              2      3      0       1       2        3
# 0  abc  100.0  abc@gmail.com    mum    NaN     NaN     NaN      NaN
# 1  bcd  200.0  def@gmail.com   pune    NaN     NaN     NaN      NaN
# 2  efg  300.0  kgf@gmail.com    mum    NaN     NaN     NaN      NaN
# 3  hij  400.0  mno@gmail.com  delhi    NaN     NaN     NaN      NaN
# 4  NaN    NaN            NaN    NaN  234.0  2334.0  2334.0       ds
# 5  NaN    NaN            NaN    NaN  456.0  5356.0  5567.0  bigdata
# 6  NaN    NaN            NaN    NaN  234.0  7478.0  7765.0   python
# 7  NaN    NaN            NaN    NaN  566.0  3887.0  5554.0      web

# %%
data7 = {'emp_id' : [101,102,103,104],
'salary' : [222,555,666,897],
'pf' : [23,34,56,78]
}

data8 = {'emp_id' : [101,102,103,104],
'mobile_no' : [2344,5677,8765,7865],
'house_no' : [345,567,876,456]
}

# %%
df7 = pd.DataFrame(data7)
df8 = pd.DataFrame(data8)

# %%
df7
# Out:
#    emp_id  salary  pf
# 0     101     222  23
# 1     102     555  34
# 2     103     666  56
# 3     104     897  78

# %%
df8
# Out:
#    emp_id  mobile_no  house_no
# 0     101       2344       345
# 1     102       5677       567
# 2     103       8765       876
# 3     104       7865       456

# %%
pd.merge(df7,df8)
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     222  23       2344       345
# 1     102     555  34       5677       567
# 2     103     666  56       8765       876
# 3     104     897  78       7865       456

# %%
pd.merge(df7,df8, how='left')
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     222  23       2344       345
# 1     102     555  34       5677       567
# 2     103     666  56       8765       876
# 3     104     897  78       7865       456

# %%
pd.merge(df7,df8, how='left',on='emp_id')
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     222  23       2344       345
# 1     102     555  34       5677       567
# 2     103     666  56       8765       876
# 3     104     897  78       7865       456

# %%
data9 = {'emp_id1' : [101,102,103,104],
'salary1' : [222,555,666,897],
'pf1' : [23,34,56,78]
}

data10 = {'emp_id2' : [101,102,103,104],
'mobile_no2' : [2344,5677,8765,7865],
'house_no2' : [345,567,876,456]
}

# %%
df9 = pd.DataFrame(data9)
df10 = pd.DataFrame(data10)

# %%
df9
# Out:
#    emp_id1  salary1  pf1
# 0      101      222   23
# 1      102      555   34
# 2      103      666   56
# 3      104      897   78

# %%
df10
# Out:
#    emp_id2  mobile_no2  house_no2
# 0      101        2344        345
# 1      102        5677        567
# 2      103        8765        876
# 3      104        7865        456

# %%
pd.merge(df9,df10 ,left_on='emp_id1',right_on='emp_id2')
# Out:
#    emp_id1  salary1  pf1  emp_id2  mobile_no2  house_no2
# 0      101      222   23      101        2344        345
# 1      102      555   34      102        5677        567
# 2      103      666   56      103        8765        876
# 3      104      897   78      104        7865        456

# %%
data11 = {'emp_id' : [101,102,103,104],
'salary' : [222,555,666,897],
'pf' : [23,34,56,78]
}

data12 = {'emp_id' : [101,102,104,105,123],
'mobile_no' : [2344,5677,8765,7865,3455],
'house_no' : [345,567,876,456,678]
}

# %%
df11 = pd.DataFrame(data11)
df12 = pd.DataFrame(data12)

# %%
df11
# Out:
#    emp_id  salary  pf
# 0     101     222  23
# 1     102     555  34
# 2     103     666  56
# 3     104     897  78

# %%
df12
# Out:
#    emp_id  mobile_no  house_no
# 0     101       2344       345
# 1     102       5677       567
# 2     104       8765       876
# 3     105       7865       456
# 4     123       3455       678

# %%
pd.merge(df11,df12)
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     222  23       2344       345
# 1     102     555  34       5677       567
# 2     104     897  78       8765       876

# %%
data13 = {'emp_id1' : [101,102,103,104],
'salary1' : [222,555,666,897],
'pf1' : [23,34,56,78]
}

data14 = {'emp_id2' : [101,102,104,105,123],
'mobile_no2' : [2344,5677,8765,7865,3455],
'house_no2' : [345,567,876,456,678]
}

# %%
df13 = pd.DataFrame(data13, index=['a','b','c','d',])
df14 = pd.DataFrame(data14, index=['a','b','d','e','f'])

# %%
df13
# Out:
#    emp_id1  salary1  pf1
# a      101      222   23
# b      102      555   34
# c      103      666   56
# d      104      897   78

# %%
df14
# Out:
#    emp_id2  mobile_no2  house_no2
# a      101        2344        345
# b      102        5677        567
# d      104        8765        876
# e      105        7865        456
# f      123        3455        678

# %%
df13.join(df14)
# Out:
#    emp_id1  salary1  pf1  emp_id2  mobile_no2  house_no2
# a      101      222   23    101.0      2344.0      345.0
# b      102      555   34    102.0      5677.0      567.0
# c      103      666   56      NaN         NaN        NaN
# d      104      897   78    104.0      8765.0      876.0

# %%
df14.join(df13)
# Out:
#    emp_id2  mobile_no2  house_no2  emp_id1  salary1   pf1
# a      101        2344        345    101.0    222.0  23.0
# b      102        5677        567    102.0    555.0  34.0
# d      104        8765        876    104.0    897.0  78.0
# e      105        7865        456      NaN      NaN   NaN
# f      123        3455        678      NaN      NaN   NaN

# %%
df

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df1

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce
# 0      Dealer       Manual      0          2025         11
# 1      Dealer       Manual      0          2025         12
# 2      Dealer       Manual      0          2025          8
# 3      Dealer       Manual      0          2025         14
# 4      Dealer       Manual      0          2025         11

# %%
df1["Present_Price"]>5

# %%
def review(x):
    if x>5:
        return("high")
    else:   
        return("low")

# %%
review(4.59)
# Out:
# 'low'

# %%
df1['Review'] = df1['Present_Price'].apply(review)

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce Review
# 0      Dealer       Manual      0          2025         11   high
# 1      Dealer       Manual      0          2025         12   high
# 2      Dealer       Manual      0          2025          8   high
# 3      Dealer       Manual      0          2025         14    low
# 4      Dealer       Manual      0          2025         11   high

# %%
df1['Present_Price'] = df1['Present_Price'].apply(review)

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Differnce Review
# ...

# %%
df1['Car_len'] = df1['Car_Name'].apply(len)

# %%
df1

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce Review
# 0      Dealer       Manual      0          2025         11   high
# 1      Dealer       Manual      0          2025         12   high
# 2      Dealer       Manual      0          2025          8   high
# 3      Dealer       Manual      0          2025         14    low
# 4      Dealer       Manual      0          2025         11   high

# %%
for i in df:
     print(i)
# Out:
# PassengerId
# Name
# Pclass
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
# Survived

# %%
for i in df:
     print(df1)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Differnce Review
# ...

# %%
for i in df1:
     print(df1[i])

# %%
df

# %%
df.head()

# %%
pd.Categorical(df)

# %%
pd.Categorical(df['Embarked'])

# %%
pd.Categorical(df['Sex'])

# %%
pd.Categorical(df['Pclass'])

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
a =["abc","def","hello","good"]

# %%
df = pd.Series(a)

# %%
df
# Out:
# 0      abc
# 1      def
# 2    hello
# 3     good
# dtype: object

# %%
df1.duplicated().sum()
# Out:
# np.int64(2)

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
df1[df1.duplicated() == True]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner  Current_Year  Differnce Review
# 17      Dealer       Manual      0          2025          9   high
# 93      Dealer    Automatic      0          2025         10   high

# %%
df1.drop_duplicates(inplace=True)

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Differnce Review
# ...

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  Differnce Review
# 0      Dealer       Manual      0          2025         11   high
# 1      Dealer       Manual      0          2025         12   high
# 2      Dealer       Manual      0          2025          8   high
# 3      Dealer       Manual      0          2025         14    low
# 4      Dealer       Manual      0          2025         11   high

# %%
df1 = df1['Year'].replace(2014,2025)

# %%
df1.head()
# Out:
# 0    2025
# 1    2013
# 2    2017
# 3    2011
# 4    2025
# Name: Year, dtype: int64
